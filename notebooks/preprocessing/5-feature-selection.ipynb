# %%
from pathlib import Path
from datetime import datetime
from os import PathLike
from typing import Union
import dateutil
import math

# data manipulation and analysis
import numpy as np 
import pandas as pd
from astral import Astral

# Visualization
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
from matplotlib.dates import date2num
import seaborn as sns
from prettytable import PrettyTable
import plotly.express as px # An interactive graphing library that makes interactive, publication-quality graphs online.
import plotly.graph_objs as go # An interactive graphing library that makes interactive, publication-quality graphs online.

# ML model selection and evaluation
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# preprocessing
from sklearn.preprocessing import LabelEncoder, StandardScaler

pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
imputed_demand_dir = '/Users/yashwanthkaruparthi/Developer/energy_demand/research/data/3-imputed/demand'
imputed_demand_path = Path(imputed_demand_dir)

imputed_weather_dir = '/Users/yashwanthkaruparthi/Developer/energy_demand/research/data/3-imputed/weather-toronto'
imputed_weather_path = Path(imputed_weather_dir)

calculated_features_dir = '/Users/yashwanthkaruparthi/Developer/energy_demand/research/data/4-calculated-features'
calculated_features_path = Path(calculated_features_dir)

interim_data_dir = '/Users/yashwanthkaruparthi/Developer/energy_demand/research/data/5-interim'
interim_data_path = Path(interim_data_dir)

clean_data_dir = '/Users/yashwanthkaruparthi/Developer/energy_demand/research/data/6-clean'
clean_data_path = Path(clean_data_dir)

# %%
df_orig = pd.read_csv('/Users/yashwanthkaruparthi/Developer/energy_demand/research/data/6-clean/clean-cut.csv')

# %%
df_orig.head()
# Out:
#             Unnamed: 0  temp  dew_point_temp  rel_hum  wind_speed  visibility
# 0  1994-01-01 00:00:00  -1.2            -3.8     83.0        15.0        19.3  \
# 1  1994-01-01 01:00:00  -0.9            -3.0     86.0        20.0        16.1
# 2  1994-01-01 02:00:00  -0.7            -3.2     83.0        15.0        16.1
# 3  1994-01-01 03:00:00  -0.8            -2.4     89.0        15.0        12.9
# 4  1994-01-01 04:00:00  -1.0            -3.3     84.0        19.0        16.1
#
#    press  hmdx  wind_chill        weather  hour_of_day    year  month
# 0  99.91   NaN        -6.0         Cloudy          0.0  1994.0    1.0  \
# 1  99.91   NaN        -6.0         Cloudy          1.0  1994.0    1.0
# 2  99.87   NaN        -5.0         Cloudy          2.0  1994.0    1.0
# 3  99.81   NaN        -5.0         Cloudy          3.0  1994.0    1.0
# 4  99.77   NaN        -6.0  Mostly Cloudy          4.0  1994.0    1.0
#
#    day_of_week  day_of_year  week_of_year  quarter  stat_hol  day_light_hours
# 0          5.0          1.0          52.0      1.0      True            False  \
# 1          5.0          1.0          52.0      1.0      True            False
# 2          5.0          1.0          52.0      1.0      True            False
# 3          5.0          1.0          52.0      1.0      True            False
# 4          5.0          1.0          52.0      1.0      True            False
#
#    hourly_demand  daily_peak
# 0        14422.0     16892.0
# 1        13845.0     16892.0
# 2        13372.0     16892.0
# 3        13025.0     16892.0
# 4        12869.0     16892.0

# %%
df_orig['Unnamed: 0'] = pd.to_datetime(df_orig['Unnamed: 0'])

# %%
dtypes = {'temp': np.float64, 'dew_point_temp':np.float64, 'rel_hum':np.float64,
          'wind_speed': np.float64, 'visibility': np.float64, 'press': np.float64,
          'hmdx': np.float64, 'wind_chill': np.float64, 'weather': object,
         'hour_of_day': np.float64, 'year': np.float64, 'month': np.float64,
         'day_of_week': np.float64, 'day_of_year': np.float64, 'week_of_year': np.float64,
          'quarter': np.float64, 'stat_hol': 'category', 'day_light_hours': 'category',
          'hourly_demand': np.float64, 'daily_peak': np.float64}

daymapper = {0.0: 'Mon', 1.0: 'Tue', 2.0: 'Wed', 3.0: 'Thu', 4.0: 'Fri', 5.0: 'Sat', 6.0: 'Sun'}
weekdaymapper = {0.0: 'Weekday', 1.0: 'Weekday', 2.0: 'Weekday', 3.0: 'Weekday', 4.0: 'Weekday',
                 5.0: 'Weekend', 6.0: 'Weekend'}
df_orig['dayofweek'] = df_orig['day_of_week'].map(daymapper)
df_orig['daytype'] = df_orig['day_of_week'].map(weekdaymapper)
df_orig['stat_hol'] = df_orig['stat_hol'].map({'True':1, 'False':0})
df_orig['day_light_hours'] = df_orig['day_light_hours'].map({'True':1, 'False':0})
df_orig['sun'] = df_orig['day_light_hours'].diff().fillna(0)

# %%
df_orig.head()
# Out:
#            Unnamed: 0  temp  dew_point_temp  rel_hum  wind_speed  visibility
# 0 1994-01-01 00:00:00  -1.2            -3.8     83.0        15.0        19.3  \
# 1 1994-01-01 01:00:00  -0.9            -3.0     86.0        20.0        16.1
# 2 1994-01-01 02:00:00  -0.7            -3.2     83.0        15.0        16.1
# 3 1994-01-01 03:00:00  -0.8            -2.4     89.0        15.0        12.9
# 4 1994-01-01 04:00:00  -1.0            -3.3     84.0        19.0        16.1
#
#    press  hmdx  wind_chill        weather  hour_of_day    year  month
# 0  99.91   NaN        -6.0         Cloudy          0.0  1994.0    1.0  \
# 1  99.91   NaN        -6.0         Cloudy          1.0  1994.0    1.0
# 2  99.87   NaN        -5.0         Cloudy          2.0  1994.0    1.0
# 3  99.81   NaN        -5.0         Cloudy          3.0  1994.0    1.0
# 4  99.77   NaN        -6.0  Mostly Cloudy          4.0  1994.0    1.0
#
#    day_of_week  day_of_year  week_of_year  quarter  stat_hol  day_light_hours
# 0          5.0          1.0          52.0      1.0       NaN              NaN  \
# 1          5.0          1.0          52.0      1.0       NaN              NaN
# 2          5.0          1.0          52.0      1.0       NaN              NaN
# 3          5.0          1.0          52.0      1.0       NaN              NaN
# 4          5.0          1.0          52.0      1.0       NaN              NaN
#
#    hourly_demand  daily_peak dayofweek  daytype  sun
# 0        14422.0     16892.0       Sat  Weekend  0.0
# 1        13845.0     16892.0       Sat  Weekend  0.0
# 2        13372.0     16892.0       Sat  Weekend  0.0
# 3        13025.0     16892.0       Sat  Weekend  0.0
# 4        12869.0     16892.0       Sat  Weekend  0.0

# %%
df_orig.tail()
# Out:
#                 Unnamed: 0  temp  dew_point_temp  rel_hum  wind_speed
# 219139 2018-12-31 19:00:00   2.5             1.0     90.0        19.0  \
# 219140 2018-12-31 20:00:00   2.9             1.6     92.0        21.0
# 219141 2018-12-31 21:00:00   3.7             2.6     93.0        21.0
# 219142 2018-12-31 22:00:00   4.0             3.0     93.0        18.0
# 219143 2018-12-31 23:00:00   4.3             3.4     94.0        12.0
#
#         visibility  press  hmdx  wind_chill   weather  hour_of_day    year
# 219139         9.7  98.51   NaN         NaN  Rain,Fog         19.0  2018.0  \
# 219140         9.7  98.17   NaN         NaN  Rain,Fog         20.0  2018.0
# 219141         9.7  97.98   NaN         NaN  Rain,Fog         21.0  2018.0
# 219142         6.4  97.61   NaN         NaN  Rain,Fog         22.0  2018.0
# 219143         9.7  97.37   NaN         NaN  Rain,Fog         23.0  2018.0
#
#         month  day_of_week  day_of_year  week_of_year  quarter  stat_hol
# 219139   12.0          0.0        365.0           1.0      4.0       NaN  \
# 219140   12.0          0.0        365.0           1.0      4.0       NaN
# 219141   12.0          0.0        365.0           1.0      4.0       NaN
# 219142   12.0          0.0        365.0           1.0      4.0       NaN
# 219143   12.0          0.0        365.0           1.0      4.0       NaN
#
#         day_light_hours  hourly_demand  daily_peak dayofweek  daytype  sun
# 219139              NaN        16195.0     17125.0       Mon  Weekday  0.0
# 219140              NaN        15668.0     17125.0       Mon  Weekday  0.0
# 219141              NaN        14987.0     17125.0       Mon  Weekday  0.0
# 219142              NaN        14560.0     17125.0       Mon  Weekday  0.0
# 219143              NaN        13828.0     17125.0       Mon  Weekday  0.0

# %%
# df = df_orig.copy(deep=True)
df = df_orig[(df_orig['Unnamed: 0'] >= '1994-01-01') & (df_orig['Unnamed: 0'] < '2019-01-01')]
df.head()
# Out:
#            Unnamed: 0  temp  dew_point_temp  rel_hum  wind_speed  visibility
# 0 1994-01-01 00:00:00  -1.2            -3.8     83.0        15.0        19.3  \
# 1 1994-01-01 01:00:00  -0.9            -3.0     86.0        20.0        16.1
# 2 1994-01-01 02:00:00  -0.7            -3.2     83.0        15.0        16.1
# 3 1994-01-01 03:00:00  -0.8            -2.4     89.0        15.0        12.9
# 4 1994-01-01 04:00:00  -1.0            -3.3     84.0        19.0        16.1
#
#    press  hmdx  wind_chill        weather  hour_of_day    year  month
# 0  99.91   NaN        -6.0         Cloudy          0.0  1994.0    1.0  \
# 1  99.91   NaN        -6.0         Cloudy          1.0  1994.0    1.0
# 2  99.87   NaN        -5.0         Cloudy          2.0  1994.0    1.0
# 3  99.81   NaN        -5.0         Cloudy          3.0  1994.0    1.0
# 4  99.77   NaN        -6.0  Mostly Cloudy          4.0  1994.0    1.0
#
#    day_of_week  day_of_year  week_of_year  quarter  stat_hol  day_light_hours
# 0          5.0          1.0          52.0      1.0       NaN              NaN  \
# 1          5.0          1.0          52.0      1.0       NaN              NaN
# 2          5.0          1.0          52.0      1.0       NaN              NaN
# 3          5.0          1.0          52.0      1.0       NaN              NaN
# 4          5.0          1.0          52.0      1.0       NaN              NaN
#
#    hourly_demand  daily_peak dayofweek  daytype  sun
# 0        14422.0     16892.0       Sat  Weekend  0.0
# 1        13845.0     16892.0       Sat  Weekend  0.0
# 2        13372.0     16892.0       Sat  Weekend  0.0
# 3        13025.0     16892.0       Sat  Weekend  0.0
# 4        12869.0     16892.0       Sat  Weekend  0.0

# %%
df.tail()
# Out:
#                 Unnamed: 0  temp  dew_point_temp  rel_hum  wind_speed
# 219139 2018-12-31 19:00:00   2.5             1.0     90.0        19.0  \
# 219140 2018-12-31 20:00:00   2.9             1.6     92.0        21.0
# 219141 2018-12-31 21:00:00   3.7             2.6     93.0        21.0
# 219142 2018-12-31 22:00:00   4.0             3.0     93.0        18.0
# 219143 2018-12-31 23:00:00   4.3             3.4     94.0        12.0
#
#         visibility  press  hmdx  wind_chill   weather  hour_of_day    year
# 219139         9.7  98.51   NaN         NaN  Rain,Fog         19.0  2018.0  \
# 219140         9.7  98.17   NaN         NaN  Rain,Fog         20.0  2018.0
# 219141         9.7  97.98   NaN         NaN  Rain,Fog         21.0  2018.0
# 219142         6.4  97.61   NaN         NaN  Rain,Fog         22.0  2018.0
# 219143         9.7  97.37   NaN         NaN  Rain,Fog         23.0  2018.0
#
#         month  day_of_week  day_of_year  week_of_year  quarter  stat_hol
# 219139   12.0          0.0        365.0           1.0      4.0       NaN  \
# 219140   12.0          0.0        365.0           1.0      4.0       NaN
# 219141   12.0          0.0        365.0           1.0      4.0       NaN
# 219142   12.0          0.0        365.0           1.0      4.0       NaN
# 219143   12.0          0.0        365.0           1.0      4.0       NaN
#
#         day_light_hours  hourly_demand  daily_peak dayofweek  daytype  sun
# 219139              NaN        16195.0     17125.0       Mon  Weekday  0.0
# 219140              NaN        15668.0     17125.0       Mon  Weekday  0.0
# 219141              NaN        14987.0     17125.0       Mon  Weekday  0.0
# 219142              NaN        14560.0     17125.0       Mon  Weekday  0.0
# 219143              NaN        13828.0     17125.0       Mon  Weekday  0.0

# %%
df_orig = df_orig.drop('daily_peak', axis=1)

# %%
df = df_orig.copy(deep=True)

df['hmdxx'] = df['temp'] + (5/9)*(6.11*math.e**(5417.7530*(1/273.16 - 1/(273.15 + df['dew_point_temp'])))-10)
# df.loc['1997-07-01'][['hmdx', 'hmdxx']].head(15)
df.head()
# Out:
#            Unnamed: 0  temp  dew_point_temp  rel_hum  wind_speed  visibility
# 0 1994-01-01 00:00:00  -1.2            -3.8     83.0        15.0        19.3  \
# 1 1994-01-01 01:00:00  -0.9            -3.0     86.0        20.0        16.1
# 2 1994-01-01 02:00:00  -0.7            -3.2     83.0        15.0        16.1
# 3 1994-01-01 03:00:00  -0.8            -2.4     89.0        15.0        12.9
# 4 1994-01-01 04:00:00  -1.0            -3.3     84.0        19.0        16.1
#
#    press  hmdx  wind_chill        weather  hour_of_day    year  month
# 0  99.91   NaN        -6.0         Cloudy          0.0  1994.0    1.0  \
# 1  99.91   NaN        -6.0         Cloudy          1.0  1994.0    1.0
# 2  99.87   NaN        -5.0         Cloudy          2.0  1994.0    1.0
# 3  99.81   NaN        -5.0         Cloudy          3.0  1994.0    1.0
# 4  99.77   NaN        -6.0  Mostly Cloudy          4.0  1994.0    1.0
#
#    day_of_week  day_of_year  week_of_year  quarter  stat_hol  day_light_hours
# 0          5.0          1.0          52.0      1.0       NaN              NaN  \
# 1          5.0          1.0          52.0      1.0       NaN              NaN
# 2          5.0          1.0          52.0      1.0       NaN              NaN
# 3          5.0          1.0          52.0      1.0       NaN              NaN
# 4          5.0          1.0          52.0      1.0       NaN              NaN
#
#    hourly_demand dayofweek  daytype  sun     hmdxx
# 0        14422.0       Sat  Weekend  0.0 -4.191500
# 1        13845.0       Sat  Weekend  0.0 -3.734133
# 2        13372.0       Sat  Weekend  0.0 -3.574269
# 3        13025.0       Sat  Weekend  0.0 -3.510459
# 4        12869.0       Sat  Weekend  0.0 -3.894137

# %%
features = ['temp', 'dew_point_temp', 'rel_hum', 'visibility', 'press', 'hmdxx']

# df_orig.set_index('Unnamed: 0', inplace=True)


keeper_cols = []
for feature in features:
    df = df.join(df.groupby(by=['year', 'day_of_year'])[feature].min(),
                           on=['year', 'day_of_year'], rsuffix='_min')
    keeper_cols.append(feature + '_min')
    df = df.join(df.groupby(by=['year', 'day_of_year'])[feature].max(),
                           on=['year', 'day_of_year'], rsuffix='_max')
    keeper_cols.append(feature + '_max')
    df = df.join(df.groupby(by=['year', 'day_of_year'])[feature].mean(),
                           on=['year', 'day_of_year'], rsuffix='_mean')
    keeper_cols.append(feature + '_mean')
    df = df.join(df.groupby(by=['year', 'day_of_year'])[feature].median(),
                           on=['year', 'day_of_year'], rsuffix='_median')
    keeper_cols.append(feature + '_median')

    # max_hours = df.loc[df.groupby(pd.Grouper(freq='D')).idxmax().loc[:, feature]]['hour_of_day'].values
    # df[feature + '_max_hour'] = np.repeat(max_hours, 24)
    # keeper_cols.append(feature + '_max_hour')

    # min_hours = df.loc[df.groupby(pd.Grouper(freq='D')).idxmin().loc[:, feature]]['hour_of_day'].values
    # df[feature + '_min_hour'] = np.repeat(min_hours, 24)
    # keeper_cols.append(feature + '_min_hour')

    # Calculate the hour of max value
    max_hours = df.loc[df.groupby(['year', 'day_of_year'])[feature].idxmax()]['hour_of_day'].values
    df[feature + '_max_hour'] = np.repeat(max_hours, 24)
    keeper_cols.append(feature + '_max_hour')

    # Calculate the hour of min value
    min_hours = df.loc[df.groupby(['year', 'day_of_year'])[feature].idxmin()]['hour_of_day'].values
    df[feature + '_min_hour'] = np.repeat(min_hours, 24)
    keeper_cols.append(feature + '_min_hour')



df.head()
# Out:
#            Unnamed: 0  temp  dew_point_temp  rel_hum  wind_speed  visibility
# 0 1994-01-01 00:00:00  -1.2            -3.8     83.0        15.0        19.3  \
# 1 1994-01-01 01:00:00  -0.9            -3.0     86.0        20.0        16.1
# 2 1994-01-01 02:00:00  -0.7            -3.2     83.0        15.0        16.1
# 3 1994-01-01 03:00:00  -0.8            -2.4     89.0        15.0        12.9
# 4 1994-01-01 04:00:00  -1.0            -3.3     84.0        19.0        16.1
#
#    press  hmdx  wind_chill        weather  hour_of_day    year  month
# 0  99.91   NaN        -6.0         Cloudy          0.0  1994.0    1.0  \
# 1  99.91   NaN        -6.0         Cloudy          1.0  1994.0    1.0
# 2  99.87   NaN        -5.0         Cloudy          2.0  1994.0    1.0
# 3  99.81   NaN        -5.0         Cloudy          3.0  1994.0    1.0
# 4  99.77   NaN        -6.0  Mostly Cloudy          4.0  1994.0    1.0
#
#    day_of_week  day_of_year  week_of_year  quarter  stat_hol  day_light_hours
# 0          5.0          1.0          52.0      1.0       NaN              NaN  \
# 1          5.0          1.0          52.0      1.0       NaN              NaN
# 2          5.0          1.0          52.0      1.0       NaN              NaN
# 3          5.0          1.0          52.0      1.0       NaN              NaN
# 4          5.0          1.0          52.0      1.0       NaN              NaN
#
#    hourly_demand dayofweek  daytype  sun     hmdxx  temp_min  temp_max
# 0        14422.0       Sat  Weekend  0.0 -4.191500      -1.8       2.8  \
# 1        13845.0       Sat  Weekend  0.0 -3.734133      -1.8       2.8
# 2        13372.0       Sat  Weekend  0.0 -3.574269      -1.8       2.8
# 3        13025.0       Sat  Weekend  0.0 -3.510459      -1.8       2.8
# 4        12869.0       Sat  Weekend  0.0 -3.894137      -1.8       2.8
#
#    temp_mean  temp_median  temp_max_hour  temp_min_hour  dew_point_temp_min
# 0      0.575         0.65           12.0            5.0                -4.8  \
# 1      0.575         0.65           12.0            5.0                -4.8
# 2      0.575         0.65           12.0            5.0                -4.8
# 3      0.575         0.65           12.0            5.0                -4.8
# 4      0.575         0.65           12.0            5.0                -4.8
#
#    dew_point_temp_max  dew_point_temp_mean  dew_point_temp_median
# 0                 1.1              -1.3875                  -0.65  \
# 1                 1.1              -1.3875                  -0.65
# 2                 1.1              -1.3875                  -0.65
# 3                 1.1              -1.3875                  -0.65
# 4                 1.1              -1.3875                  -0.65
#
#    dew_point_temp_max_hour  dew_point_temp_min_hour  rel_hum_min  rel_hum_max
# 0                     19.0                      7.0         73.0         99.0  \
# 1                     19.0                      7.0         73.0         99.0
# 2                     19.0                      7.0         73.0         99.0
# 3                     19.0                      7.0         73.0         99.0
# 4                     19.0                      7.0         73.0         99.0
#
#    rel_hum_mean  rel_hum_median  rel_hum_max_hour  rel_hum_min_hour
# 0          87.0            86.5              14.0               9.0  \
# 1          87.0            86.5              14.0               9.0
# 2          87.0            86.5              14.0               9.0
# 3          87.0            86.5              14.0               9.0
# 4          87.0            86.5              14.0               9.0
#
#    visibility_min  visibility_max  visibility_mean  visibility_median
# 0             0.8            40.2        17.841667               16.1  \
# 1             0.8            40.2        17.841667               16.1
# 2             0.8            40.2        17.841667               16.1
# 3             0.8            40.2        17.841667               16.1
# 4             0.8            40.2        17.841667               16.1
#
#    visibility_max_hour  visibility_min_hour  press_min  press_max  press_mean
# 0                 11.0                 14.0      98.51      99.91   99.075833  \
# 1                 11.0                 14.0      98.51      99.91   99.075833
# 2                 11.0                 14.0      98.51      99.91   99.075833
# 3                 11.0                 14.0      98.51      99.91   99.075833
# 4                 11.0                 14.0      98.51      99.91   99.075833
#
#    press_median  press_max_hour  press_min_hour  hmdxx_min  hmdxx_max
# 0         98.84             0.0            16.0  -4.976663   0.686009  \
# 1         98.84             0.0            16.0  -4.976663   0.686009
# 2         98.84             0.0            16.0  -4.976663   0.686009
# 3         98.84             0.0            16.0  -4.976663   0.686009
# 4         98.84             0.0            16.0  -4.976663   0.686009
#
#    hmdxx_mean  hmdxx_median  hmdxx_max_hour  hmdxx_min_hour
# 0     -1.8849     -1.513575            13.0             7.0
# 1     -1.8849     -1.513575            13.0             7.0
# 2     -1.8849     -1.513575            13.0             7.0
# 3     -1.8849     -1.513575            13.0             7.0
# 4     -1.8849     -1.513575            13.0             7.0

# %%
df.shape
# Out:
# (219144, 60)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'temp', 'dew_point_temp', 'rel_hum', 'wind_speed',
#        'visibility', 'press', 'hmdx', 'wind_chill', 'weather', 'hour_of_day',
#        'year', 'month', 'day_of_week', 'day_of_year', 'week_of_year',
#        'quarter', 'stat_hol', 'day_light_hours', 'hourly_demand', 'dayofweek',
#        'daytype', 'sun', 'hmdxx', 'temp_min', 'temp_max', 'temp_mean',
#        'temp_median', 'temp_max_hour', 'temp_min_hour', 'dew_point_temp_min',
#        'dew_point_temp_max', 'dew_point_temp_mean', 'dew_point_temp_median',
#        'dew_point_temp_max_hour', 'dew_point_temp_min_hour', 'rel_hum_min',
#        'rel_hum_max', 'rel_hum_mean', 'rel_hum_median', 'rel_hum_max_hour',
#        'rel_hum_min_hour', 'visibility_min', 'visibility_max',
#        'visibility_mean', 'visibility_median', 'visibility_max_hour',
#        'visibility_min_hour', 'press_min', 'press_max', 'press_mean',
#        'press_median', 'press_max_hour', 'press_min_hour', 'hmdxx_min',
#        'hmdxx_max', 'hmdxx_mean', 'hmdxx_median', 'hmdxx_max_hour',
#        'hmdxx_min_hour'],
#       dtype='object')

# %%
drop_columns = ['dayofweek', 'daytype', 'sun', 'day_light_hours', 'hmdx', 'hmdxx_max_hour', 'hmdxx_min_hour', 'stat_hol', 'rel_hum_max_hour', 'rel_hum_min_hour', 'dew_point_temp_max_hour', 'dew_point_temp_min_hour', 'press_max_hour', 'press_min_hour']
df.drop(columns = drop_columns, inplace=True)

# %%
df.shape
# Out:
# (219144, 46)

# %%
df.rename(columns={'Unnamed: 0': 'datetime'}, inplace=True)

# %%
df.head()
# Out:
#              datetime  temp  dew_point_temp  rel_hum  wind_speed  visibility
# 0 1994-01-01 00:00:00  -1.2            -3.8     83.0        15.0        19.3  \
# 1 1994-01-01 01:00:00  -0.9            -3.0     86.0        20.0        16.1
# 2 1994-01-01 02:00:00  -0.7            -3.2     83.0        15.0        16.1
# 3 1994-01-01 03:00:00  -0.8            -2.4     89.0        15.0        12.9
# 4 1994-01-01 04:00:00  -1.0            -3.3     84.0        19.0        16.1
#
#    press  wind_chill        weather  hour_of_day    year  month  day_of_week
# 0  99.91        -6.0         Cloudy          0.0  1994.0    1.0          5.0  \
# 1  99.91        -6.0         Cloudy          1.0  1994.0    1.0          5.0
# 2  99.87        -5.0         Cloudy          2.0  1994.0    1.0          5.0
# 3  99.81        -5.0         Cloudy          3.0  1994.0    1.0          5.0
# 4  99.77        -6.0  Mostly Cloudy          4.0  1994.0    1.0          5.0
#
#    day_of_year  week_of_year  quarter  hourly_demand     hmdxx  temp_min
# 0          1.0          52.0      1.0        14422.0 -4.191500      -1.8  \
# 1          1.0          52.0      1.0        13845.0 -3.734133      -1.8
# 2          1.0          52.0      1.0        13372.0 -3.574269      -1.8
# 3          1.0          52.0      1.0        13025.0 -3.510459      -1.8
# 4          1.0          52.0      1.0        12869.0 -3.894137      -1.8
#
#    temp_max  temp_mean  temp_median  temp_max_hour  temp_min_hour
# 0       2.8      0.575         0.65           12.0            5.0  \
# 1       2.8      0.575         0.65           12.0            5.0
# 2       2.8      0.575         0.65           12.0            5.0
# 3       2.8      0.575         0.65           12.0            5.0
# 4       2.8      0.575         0.65           12.0            5.0
#
#    dew_point_temp_min  dew_point_temp_max  dew_point_temp_mean
# 0                -4.8                 1.1              -1.3875  \
# 1                -4.8                 1.1              -1.3875
# 2                -4.8                 1.1              -1.3875
# 3                -4.8                 1.1              -1.3875
# 4                -4.8                 1.1              -1.3875
#
#    dew_point_temp_median  rel_hum_min  rel_hum_max  rel_hum_mean
# 0                  -0.65         73.0         99.0          87.0  \
# 1                  -0.65         73.0         99.0          87.0
# 2                  -0.65         73.0         99.0          87.0
# 3                  -0.65         73.0         99.0          87.0
# 4                  -0.65         73.0         99.0          87.0
#
#    rel_hum_median  visibility_min  visibility_max  visibility_mean
# 0            86.5             0.8            40.2        17.841667  \
# 1            86.5             0.8            40.2        17.841667
# 2            86.5             0.8            40.2        17.841667
# 3            86.5             0.8            40.2        17.841667
# 4            86.5             0.8            40.2        17.841667
#
#    visibility_median  visibility_max_hour  visibility_min_hour  press_min
# 0               16.1                 11.0                 14.0      98.51  \
# 1               16.1                 11.0                 14.0      98.51
# 2               16.1                 11.0                 14.0      98.51
# 3               16.1                 11.0                 14.0      98.51
# 4               16.1                 11.0                 14.0      98.51
#
#    press_max  press_mean  press_median  hmdxx_min  hmdxx_max  hmdxx_mean
# 0      99.91   99.075833         98.84  -4.976663   0.686009     -1.8849  \
# 1      99.91   99.075833         98.84  -4.976663   0.686009     -1.8849
# 2      99.91   99.075833         98.84  -4.976663   0.686009     -1.8849
# 3      99.91   99.075833         98.84  -4.976663   0.686009     -1.8849
# 4      99.91   99.075833         98.84  -4.976663   0.686009     -1.8849
#
#    hmdxx_median
# 0     -1.513575
# 1     -1.513575
# 2     -1.513575
# 3     -1.513575
# 4     -1.513575

# %%
if df.index.name=='datetime':
  print('True')
else:
  df.set_index('datetime', inplace=True)
  print('datetime is now indexed')
# Out:
# datetime is now indexed

# %%
df.columns
# Out:
# Index(['temp', 'dew_point_temp', 'rel_hum', 'wind_speed', 'visibility',
#        'press', 'wind_chill', 'weather', 'hour_of_day', 'year', 'month',
#        'day_of_week', 'day_of_year', 'week_of_year', 'quarter',
#        'hourly_demand', 'hmdxx', 'temp_min', 'temp_max', 'temp_mean',
#        'temp_median', 'temp_max_hour', 'temp_min_hour', 'dew_point_temp_min',
#        'dew_point_temp_max', 'dew_point_temp_mean', 'dew_point_temp_median',
#        'rel_hum_min', 'rel_hum_max', 'rel_hum_mean', 'rel_hum_median',
#        'visibility_min', 'visibility_max', 'visibility_mean',
#        'visibility_median', 'visibility_max_hour', 'visibility_min_hour',
#        'press_min', 'press_max', 'press_mean', 'press_median', 'hmdxx_min',
#        'hmdxx_max', 'hmdxx_mean', 'hmdxx_median'],
#       dtype='object')

# %%
duplicated_columns = df.columns[df.columns.duplicated()]

if duplicated_columns.empty:
    print("No duplicated columns found.")
else:
    print("Duplicated columns found:")
    print(duplicated_columns)
# Out:
# No duplicated columns found.

# %%
df.tail()
# Out:
#                      temp  dew_point_temp  rel_hum  wind_speed  visibility
# datetime
# 2018-12-31 19:00:00   2.5             1.0     90.0        19.0         9.7  \
# 2018-12-31 20:00:00   2.9             1.6     92.0        21.0         9.7
# 2018-12-31 21:00:00   3.7             2.6     93.0        21.0         9.7
# 2018-12-31 22:00:00   4.0             3.0     93.0        18.0         6.4
# 2018-12-31 23:00:00   4.3             3.4     94.0        12.0         9.7
#
#                      press  wind_chill   weather  hour_of_day    year  month
# datetime
# 2018-12-31 19:00:00  98.51         NaN  Rain,Fog         19.0  2018.0   12.0  \
# 2018-12-31 20:00:00  98.17         NaN  Rain,Fog         20.0  2018.0   12.0
# 2018-12-31 21:00:00  97.98         NaN  Rain,Fog         21.0  2018.0   12.0
# 2018-12-31 22:00:00  97.61         NaN  Rain,Fog         22.0  2018.0   12.0
# 2018-12-31 23:00:00  97.37         NaN  Rain,Fog         23.0  2018.0   12.0
#
#                      day_of_week  day_of_year  week_of_year  quarter
# datetime
# 2018-12-31 19:00:00          0.0        365.0           1.0      4.0  \
# 2018-12-31 20:00:00          0.0        365.0           1.0      4.0
# 2018-12-31 21:00:00          0.0        365.0           1.0      4.0
# 2018-12-31 22:00:00          0.0        365.0           1.0      4.0
# 2018-12-31 23:00:00          0.0        365.0           1.0      4.0
#
#                      hourly_demand     hmdxx  temp_min  temp_max  temp_mean
# datetime
# 2018-12-31 19:00:00        16195.0  0.590925      -2.0       4.3   1.204167  \
# 2018-12-31 20:00:00        15668.0  1.151739      -2.0       4.3   1.204167
# 2018-12-31 21:00:00        14987.0  2.233969      -2.0       4.3   1.204167
# 2018-12-31 22:00:00        14560.0  2.652024      -2.0       4.3   1.204167
# 2018-12-31 23:00:00        13828.0  3.073132      -2.0       4.3   1.204167
#
#                      temp_median  temp_max_hour  temp_min_hour
# datetime
# 2018-12-31 19:00:00         2.25           23.0            5.0  \
# 2018-12-31 20:00:00         2.25           23.0            5.0
# 2018-12-31 21:00:00         2.25           23.0            5.0
# 2018-12-31 22:00:00         2.25           23.0            5.0
# 2018-12-31 23:00:00         2.25           23.0            5.0
#
#                      dew_point_temp_min  dew_point_temp_max
# datetime
# 2018-12-31 19:00:00                -6.4                 3.4  \
# 2018-12-31 20:00:00                -6.4                 3.4
# 2018-12-31 21:00:00                -6.4                 3.4
# 2018-12-31 22:00:00                -6.4                 3.4
# 2018-12-31 23:00:00                -6.4                 3.4
#
#                      dew_point_temp_mean  dew_point_temp_median  rel_hum_min
# datetime
# 2018-12-31 19:00:00            -1.645833                   -1.3         65.0  \
# 2018-12-31 20:00:00            -1.645833                   -1.3         65.0
# 2018-12-31 21:00:00            -1.645833                   -1.3         65.0
# 2018-12-31 22:00:00            -1.645833                   -1.3         65.0
# 2018-12-31 23:00:00            -1.645833                   -1.3         65.0
#
#                      rel_hum_max  rel_hum_mean  rel_hum_median
# datetime
# 2018-12-31 19:00:00         94.0     81.708333            82.5  \
# 2018-12-31 20:00:00         94.0     81.708333            82.5
# 2018-12-31 21:00:00         94.0     81.708333            82.5
# 2018-12-31 22:00:00         94.0     81.708333            82.5
# 2018-12-31 23:00:00         94.0     81.708333            82.5
#
#                      visibility_min  visibility_max  visibility_mean
# datetime
# 2018-12-31 19:00:00             4.8            24.1        18.091667  \
# 2018-12-31 20:00:00             4.8            24.1        18.091667
# 2018-12-31 21:00:00             4.8            24.1        18.091667
# 2018-12-31 22:00:00             4.8            24.1        18.091667
# 2018-12-31 23:00:00             4.8            24.1        18.091667
#
#                      visibility_median  visibility_max_hour
# datetime
# 2018-12-31 19:00:00               24.1                  0.0  \
# 2018-12-31 20:00:00               24.1                  0.0
# 2018-12-31 21:00:00               24.1                  0.0
# 2018-12-31 22:00:00               24.1                  0.0
# 2018-12-31 23:00:00               24.1                  0.0
#
#                      visibility_min_hour  press_min  press_max  press_mean
# datetime
# 2018-12-31 19:00:00                 17.0      97.37     100.03     99.3025  \
# 2018-12-31 20:00:00                 17.0      97.37     100.03     99.3025
# 2018-12-31 21:00:00                 17.0      97.37     100.03     99.3025
# 2018-12-31 22:00:00                 17.0      97.37     100.03     99.3025
# 2018-12-31 23:00:00                 17.0      97.37     100.03     99.3025
#
#                      press_median  hmdxx_min  hmdxx_max  hmdxx_mean
# datetime
# 2018-12-31 19:00:00        99.695  -5.229812   3.073132    -1.27833  \
# 2018-12-31 20:00:00        99.695  -5.229812   3.073132    -1.27833
# 2018-12-31 21:00:00        99.695  -5.229812   3.073132    -1.27833
# 2018-12-31 22:00:00        99.695  -5.229812   3.073132    -1.27833
# 2018-12-31 23:00:00        99.695  -5.229812   3.073132    -1.27833
#
#                      hmdxx_median
# datetime
# 2018-12-31 19:00:00      0.062595
# 2018-12-31 20:00:00      0.062595
# 2018-12-31 21:00:00      0.062595
# 2018-12-31 22:00:00      0.062595
# 2018-12-31 23:00:00      0.062595

# %%
df.to_csv(clean_data_path/"for_todaily_conversion.csv")

# %%
clean_pre_df = df.copy(deep=True)

# %%
clean_pre_df.head()
# Out:
#                      temp  dew_point_temp  rel_hum  wind_speed  visibility
# datetime
# 1994-01-01 00:00:00  -1.2            -3.8     83.0        15.0        19.3  \
# 1994-01-01 01:00:00  -0.9            -3.0     86.0        20.0        16.1
# 1994-01-01 02:00:00  -0.7            -3.2     83.0        15.0        16.1
# 1994-01-01 03:00:00  -0.8            -2.4     89.0        15.0        12.9
# 1994-01-01 04:00:00  -1.0            -3.3     84.0        19.0        16.1
#
#                      press  wind_chill        weather  hour_of_day    year
# datetime
# 1994-01-01 00:00:00  99.91        -6.0         Cloudy          0.0  1994.0  \
# 1994-01-01 01:00:00  99.91        -6.0         Cloudy          1.0  1994.0
# 1994-01-01 02:00:00  99.87        -5.0         Cloudy          2.0  1994.0
# 1994-01-01 03:00:00  99.81        -5.0         Cloudy          3.0  1994.0
# 1994-01-01 04:00:00  99.77        -6.0  Mostly Cloudy          4.0  1994.0
#
#                      month  day_of_week  day_of_year  week_of_year  quarter
# datetime
# 1994-01-01 00:00:00    1.0          5.0          1.0          52.0      1.0  \
# 1994-01-01 01:00:00    1.0          5.0          1.0          52.0      1.0
# 1994-01-01 02:00:00    1.0          5.0          1.0          52.0      1.0
# 1994-01-01 03:00:00    1.0          5.0          1.0          52.0      1.0
# 1994-01-01 04:00:00    1.0          5.0          1.0          52.0      1.0
#
#                      hourly_demand     hmdxx  temp_min  temp_max  temp_mean
# datetime
# 1994-01-01 00:00:00        14422.0 -4.191500      -1.8       2.8      0.575  \
# 1994-01-01 01:00:00        13845.0 -3.734133      -1.8       2.8      0.575
# 1994-01-01 02:00:00        13372.0 -3.574269      -1.8       2.8      0.575
# 1994-01-01 03:00:00        13025.0 -3.510459      -1.8       2.8      0.575
# 1994-01-01 04:00:00        12869.0 -3.894137      -1.8       2.8      0.575
#
#                      temp_median  temp_max_hour  temp_min_hour
# datetime
# 1994-01-01 00:00:00         0.65           12.0            5.0  \
# 1994-01-01 01:00:00         0.65           12.0            5.0
# 1994-01-01 02:00:00         0.65           12.0            5.0
# 1994-01-01 03:00:00         0.65           12.0            5.0
# 1994-01-01 04:00:00         0.65           12.0            5.0
#
#                      dew_point_temp_min  dew_point_temp_max
# datetime
# 1994-01-01 00:00:00                -4.8                 1.1  \
# 1994-01-01 01:00:00                -4.8                 1.1
# 1994-01-01 02:00:00                -4.8                 1.1
# 1994-01-01 03:00:00                -4.8                 1.1
# 1994-01-01 04:00:00                -4.8                 1.1
#
#                      dew_point_temp_mean  dew_point_temp_median  rel_hum_min
# datetime
# 1994-01-01 00:00:00              -1.3875                  -0.65         73.0  \
# 1994-01-01 01:00:00              -1.3875                  -0.65         73.0
# 1994-01-01 02:00:00              -1.3875                  -0.65         73.0
# 1994-01-01 03:00:00              -1.3875                  -0.65         73.0
# 1994-01-01 04:00:00              -1.3875                  -0.65         73.0
#
#                      rel_hum_max  rel_hum_mean  rel_hum_median
# datetime
# 1994-01-01 00:00:00         99.0          87.0            86.5  \
# 1994-01-01 01:00:00         99.0          87.0            86.5
# 1994-01-01 02:00:00         99.0          87.0            86.5
# 1994-01-01 03:00:00         99.0          87.0            86.5
# 1994-01-01 04:00:00         99.0          87.0            86.5
#
#                      visibility_min  visibility_max  visibility_mean
# datetime
# 1994-01-01 00:00:00             0.8            40.2        17.841667  \
# 1994-01-01 01:00:00             0.8            40.2        17.841667
# 1994-01-01 02:00:00             0.8            40.2        17.841667
# 1994-01-01 03:00:00             0.8            40.2        17.841667
# 1994-01-01 04:00:00             0.8            40.2        17.841667
#
#                      visibility_median  visibility_max_hour
# datetime
# 1994-01-01 00:00:00               16.1                 11.0  \
# 1994-01-01 01:00:00               16.1                 11.0
# 1994-01-01 02:00:00               16.1                 11.0
# 1994-01-01 03:00:00               16.1                 11.0
# 1994-01-01 04:00:00               16.1                 11.0
#
#                      visibility_min_hour  press_min  press_max  press_mean
# datetime
# 1994-01-01 00:00:00                 14.0      98.51      99.91   99.075833  \
# 1994-01-01 01:00:00                 14.0      98.51      99.91   99.075833
# 1994-01-01 02:00:00                 14.0      98.51      99.91   99.075833
# 1994-01-01 03:00:00                 14.0      98.51      99.91   99.075833
# 1994-01-01 04:00:00                 14.0      98.51      99.91   99.075833
#
#                      press_median  hmdxx_min  hmdxx_max  hmdxx_mean
# datetime
# 1994-01-01 00:00:00         98.84  -4.976663   0.686009     -1.8849  \
# 1994-01-01 01:00:00         98.84  -4.976663   0.686009     -1.8849
# 1994-01-01 02:00:00         98.84  -4.976663   0.686009     -1.8849
# 1994-01-01 03:00:00         98.84  -4.976663   0.686009     -1.8849
# 1994-01-01 04:00:00         98.84  -4.976663   0.686009     -1.8849
#
#                      hmdxx_median
# datetime
# 1994-01-01 00:00:00     -1.513575
# 1994-01-01 01:00:00     -1.513575
# 1994-01-01 02:00:00     -1.513575
# 1994-01-01 03:00:00     -1.513575
# 1994-01-01 04:00:00     -1.513575

# %% [markdown]
# For exporting hourly data, we drop weather columns related to min, max, mean, median

# %%
clean_pre_df.columns
# Out:
# Index(['temp', 'dew_point_temp', 'rel_hum', 'wind_speed', 'visibility',
#        'press', 'wind_chill', 'weather', 'hour_of_day', 'year', 'month',
#        'day_of_week', 'day_of_year', 'week_of_year', 'quarter',
#        'hourly_demand', 'hmdxx', 'temp_min', 'temp_max', 'temp_mean',
#        'temp_median', 'temp_max_hour', 'temp_min_hour', 'dew_point_temp_min',
#        'dew_point_temp_max', 'dew_point_temp_mean', 'dew_point_temp_median',
#        'rel_hum_min', 'rel_hum_max', 'rel_hum_mean', 'rel_hum_median',
#        'visibility_min', 'visibility_max', 'visibility_mean',
#        'visibility_median', 'visibility_max_hour', 'visibility_min_hour',
#        'press_min', 'press_max', 'press_mean', 'press_median', 'hmdxx_min',
#        'hmdxx_max', 'hmdxx_mean', 'hmdxx_median'],
#       dtype='object')

# %%
drop_columns_2 = ['temp_min', 'temp_max', 'temp_mean',
       'temp_median', 'temp_max_hour', 'temp_min_hour', 'dew_point_temp_min',
       'dew_point_temp_max', 'dew_point_temp_mean', 'dew_point_temp_median',
       'rel_hum_min', 'rel_hum_max', 'rel_hum_mean', 'rel_hum_median',
       'visibility_min', 'visibility_max', 'visibility_mean',
       'visibility_median', 'visibility_max_hour', 'visibility_min_hour',
       'press_min', 'press_max', 'press_mean', 'press_median', 'hmdxx_min',
       'hmdxx_max', 'hmdxx_mean', 'hmdxx_median']

clean_pre_df.drop(columns = drop_columns_2, inplace=True)

# %%
clean_pre_df.shape
# Out:
# (219144, 17)

# %%
clean_pre_df.head(30)
# Out:
#                      temp  dew_point_temp  rel_hum  wind_speed  visibility
# datetime
# 1994-01-01 00:00:00  -1.2            -3.8     83.0        15.0        19.3  \
# 1994-01-01 01:00:00  -0.9            -3.0     86.0        20.0        16.1
# 1994-01-01 02:00:00  -0.7            -3.2     83.0        15.0        16.1
# 1994-01-01 03:00:00  -0.8            -2.4     89.0        15.0        12.9
# 1994-01-01 04:00:00  -1.0            -3.3     84.0        19.0        16.1
# 1994-01-01 05:00:00  -1.8            -3.6     87.0        11.0        16.1
# 1994-01-01 06:00:00  -1.7            -3.9     85.0        15.0        19.3
# 1994-01-01 07:00:00  -1.8            -4.8     80.0        15.0        16.1
# 1994-01-01 08:00:00  -0.5            -3.8     78.0        17.0        25.0
# 1994-01-01 09:00:00   0.5            -3.7     73.0        24.0        25.0
# 1994-01-01 10:00:00   1.4            -2.9     73.0        26.0        25.0
# 1994-01-01 11:00:00   2.5            -0.9     78.0        31.0        40.2
# 1994-01-01 12:00:00   2.8            -0.4     80.0        26.0        40.2
# 1994-01-01 13:00:00   2.8             0.2     83.0        30.0        24.1
# 1994-01-01 14:00:00   0.4             0.2     99.0        24.0         0.8
# 1994-01-01 15:00:00   0.7             0.0     95.0        20.0         1.6
# 1994-01-01 16:00:00   0.6             0.0     96.0        22.0        12.9
# 1994-01-01 17:00:00   1.5             0.5     93.0        22.0        12.9
# 1994-01-01 18:00:00   1.4             0.5     94.0        22.0         8.0
# 1994-01-01 19:00:00   1.9             1.1     95.0        20.0        12.9
# 1994-01-01 20:00:00   2.2             0.6     89.0        20.0        19.3
# 1994-01-01 21:00:00   1.8             1.1     95.0        20.0        16.1
# 1994-01-01 22:00:00   1.9             1.1     95.0        24.0        16.1
# 1994-01-01 23:00:00   1.8             1.1     95.0        15.0        16.1
# 1994-01-02 00:00:00   1.7             0.5     92.0        13.0        19.3
# 1994-01-02 01:00:00   1.2            -0.5     88.0        22.0        25.0
# 1994-01-02 02:00:00  -0.7            -2.7     86.0        22.0        25.0
# 1994-01-02 03:00:00  -3.0            -8.8     64.0        28.0        25.0
# 1994-01-02 04:00:00  -5.0            -9.7     69.0        24.0        25.0
# 1994-01-02 05:00:00  -6.5            -9.7     78.0        20.0        25.0
#
#                      press  wind_chill            weather  hour_of_day
# datetime
# 1994-01-01 00:00:00  99.91        -6.0             Cloudy          0.0  \
# 1994-01-01 01:00:00  99.91        -6.0             Cloudy          1.0
# 1994-01-01 02:00:00  99.87        -5.0             Cloudy          2.0
# 1994-01-01 03:00:00  99.81        -5.0             Cloudy          3.0
# 1994-01-01 04:00:00  99.77        -6.0      Mostly Cloudy          4.0
# 1994-01-01 05:00:00  99.67        -6.0             Cloudy          5.0
# 1994-01-01 06:00:00  99.57        -7.0             Cloudy          6.0
# 1994-01-01 07:00:00  99.37        -7.0      Mostly Cloudy          7.0
# 1994-01-01 08:00:00  99.31        -5.0      Mostly Cloudy          8.0
# 1994-01-01 09:00:00  99.14         NaN      Mostly Cloudy          9.0
# 1994-01-01 10:00:00  99.04         NaN             Cloudy         10.0
# 1994-01-01 11:00:00  98.91         NaN             Cloudy         11.0
# 1994-01-01 12:00:00  98.77         NaN             Cloudy         12.0
# 1994-01-01 13:00:00  98.67         NaN               Snow         13.0
# 1994-01-01 14:00:00  98.61         NaN  Moderate Snow,Fog         14.0
# 1994-01-01 15:00:00  98.57         NaN           Snow,Fog         15.0
# 1994-01-01 16:00:00  98.51         NaN               Snow         16.0
# 1994-01-01 17:00:00  98.54         NaN             Cloudy         17.0
# 1994-01-01 18:00:00  98.57         NaN          Rain,Snow         18.0
# 1994-01-01 19:00:00  98.61         NaN             Cloudy         19.0
# 1994-01-01 20:00:00  98.61         NaN               Snow         20.0
# 1994-01-01 21:00:00  98.67         NaN               Rain         21.0
# 1994-01-01 22:00:00  98.67         NaN               Rain         22.0
# 1994-01-01 23:00:00  98.74         NaN               Rain         23.0
# 1994-01-02 00:00:00  98.77         NaN               Rain          0.0
# 1994-01-02 01:00:00  98.84         NaN      Mostly Cloudy          1.0
# 1994-01-02 02:00:00  98.97        -6.0      Mostly Cloudy          2.0
# 1994-01-02 03:00:00  99.17       -10.0       Mainly Clear          3.0
# 1994-01-02 04:00:00  99.27       -12.0      Mostly Cloudy          4.0
# 1994-01-02 05:00:00  99.41       -13.0      Mostly Cloudy          5.0
#
#                        year  month  day_of_week  day_of_year  week_of_year
# datetime
# 1994-01-01 00:00:00  1994.0    1.0          5.0          1.0          52.0  \
# 1994-01-01 01:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 02:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 03:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 04:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 05:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 06:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 07:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 08:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 09:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 10:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 11:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 12:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 13:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 14:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 15:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 16:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 17:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 18:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 19:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 20:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 21:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 22:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-01 23:00:00  1994.0    1.0          5.0          1.0          52.0
# 1994-01-02 00:00:00  1994.0    1.0          6.0          2.0          52.0
# 1994-01-02 01:00:00  1994.0    1.0          6.0          2.0          52.0
# 1994-01-02 02:00:00  1994.0    1.0          6.0          2.0          52.0
# 1994-01-02 03:00:00  1994.0    1.0          6.0          2.0          52.0
# 1994-01-02 04:00:00  1994.0    1.0          6.0          2.0          52.0
# 1994-01-02 05:00:00  1994.0    1.0          6.0          2.0          52.0
#
#                      quarter  hourly_demand      hmdxx
# datetime
# 1994-01-01 00:00:00      1.0        14422.0  -4.191500
# 1994-01-01 01:00:00      1.0        13845.0  -3.734133
# 1994-01-01 02:00:00      1.0        13372.0  -3.574269
# 1994-01-01 03:00:00      1.0        13025.0  -3.510459
# 1994-01-01 04:00:00      1.0        12869.0  -3.894137
# 1994-01-01 05:00:00      1.0        12866.0  -4.752946
# 1994-01-01 06:00:00      1.0        13015.0  -4.710583
# 1994-01-01 07:00:00      1.0        13577.0  -4.976663
# 1994-01-01 08:00:00      1.0        13567.0  -3.491500
# 1994-01-01 09:00:00      1.0        14130.0  -2.472288
# 1994-01-01 10:00:00      1.0        14714.0  -1.413863
# 1994-01-01 11:00:00      1.0        15179.0   0.121154
# 1994-01-01 12:00:00      1.0        14449.0   0.539180
# 1994-01-01 13:00:00      1.0        15407.0   0.686009
# 1994-01-01 14:00:00      1.0        15436.0  -1.713991
# 1994-01-01 15:00:00      1.0        15510.0  -1.463575
# 1994-01-01 16:00:00      1.0        16074.0  -1.563575
# 1994-01-01 17:00:00      1.0        16892.0  -0.538394
# 1994-01-01 18:00:00      1.0        16652.0  -0.638394
# 1994-01-01 19:00:00      1.0        16261.0   0.017296
# 1994-01-01 20:00:00      1.0        15872.0   0.187135
# 1994-01-01 21:00:00      1.0        15505.0  -0.082704
# 1994-01-01 22:00:00      1.0        14934.0   0.017296
# 1994-01-01 23:00:00      1.0        14152.0  -0.082704
# 1994-01-02 00:00:00      1.0        13440.0  -0.338394
# 1994-01-02 01:00:00      1.0        13054.0  -1.084736
# 1994-01-02 02:00:00      1.0        12760.0  -3.472914
# 1994-01-02 03:00:00      1.0        12782.0  -6.802879
# 1994-01-02 04:00:00      1.0        12874.0  -8.921393
# 1994-01-02 05:00:00      1.0        13112.0 -10.421393

# %%
object_cols = clean_pre_df.select_dtypes(include=['object']).columns

print("columns with object dtype: ")
for col in object_cols:
  print(col)
# Out:
# columns with object dtype:
# weather

# %%
clean_pre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 219144 entries, 1994-01-01 00:00:00 to 2018-12-31 23:00:00
# Data columns (total 17 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   temp            219144 non-null  float64
#  1   dew_point_temp  219144 non-null  float64
#  2   rel_hum         219144 non-null  float64
#  3   wind_speed      219144 non-null  float64
#  4   visibility      219144 non-null  float64
#  5   press           219144 non-null  float64
#  6   wind_chill      48918 non-null   float64
#  7   weather         191347 non-null  object
#  8   hour_of_day     219144 non-null  float64
#  9   year            219144 non-null  float64
#  10  month           219144 non-null  float64
#  11  day_of_week     219144 non-null  float64
#  12  day_of_year     219144 non-null  float64
#  13  week_of_year    219144 non-null  float64
#  14  quarter         219144 non-null  float64
#  15  hourly_demand   219144 non-null  float64
#  16  hmdxx           219144 non-null  float64
# dtypes: float64(16), object(1)
# memory usage: 30.1+ MB

# %%
clean_pre_df['weather'].unique()
# Out:
# array(['Cloudy', 'Mostly Cloudy', 'Snow', 'Moderate Snow,Fog', 'Snow,Fog',
#        'Rain,Snow', 'Rain', 'Mainly Clear', 'Snow Showers', 'Clear',
#        'Snow,Blowing Snow', 'Snow Showers,Blowing Snow', 'Fog',
#        'Fog,Blowing Snow', 'Snow Grains', 'Freezing Drizzle,Fog',
#        'Drizzle,Fog', 'Drizzle', 'Haze', 'Freezing Rain,Fog', 'Rain,Fog',
#        'Rain,Drizzle,Fog', nan, 'Ice Fog', 'Snow,Snow Grains',
#        'Moderate Snow', 'Blowing Snow', 'Moderate Snow,Snow Grains',
#        'Moderate Snow,Snow Grains,Blowing Snow',
#        'Snow,Snow Grains,Blowing Snow', 'Snow,Ice Pellets,Blowing Snow',
#        'Moderate Snow,Blowing Snow', 'Snow Showers,Fog',
#        'Freezing Drizzle,Snow Grains', 'Snow Grains,Fog', 'Rain Showers',
#        'Rain,Snow,Fog', 'Moderate Rain,Fog', 'Snow,Snow Grains,Fog',
#        'Rain Showers,Snow Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Haze', 'Rain,Haze', 'Thunderstorms,Haze',
#        'Thunderstorms,Rain Showers',
#        'Thunderstorms,Moderate Rain Showers,Fog',
#        'Moderate Rain Showers,Fog', 'Rain,Ice Pellets',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog', 'Moderate Rain Showers',
#        'Heavy Rain Showers', 'Thunderstorms,Heavy Rain Showers,Fog',
#        'Thunderstorms,Moderate Rain Showers', 'Heavy Rain',
#        'Heavy Thunderstorms,Heavy Rain Showers',
#        'Heavy Thunderstorms,Heavy Rain Showers,Fog',
#        'Heavy Rain Showers,Fog', 'Ice Pellet Showers,Snow Showers',
#        'Ice Pellet Showers,Snow Showers,Snow Pellets', 'Freezing Rain',
#        'Ice Crystals', 'Freezing Rain,Freezing Drizzle,Fog',
#        'Freezing Rain,Ice Pellets,Fog', 'Snow Pellets', 'Drizzle,Snow',
#        'Rain,Ice Pellets,Fog', 'Drizzle,Snow,Fog',
#        'Freezing Drizzle,Snow Grains,Fog', 'Heavy Rain,Fog',
#        'Freezing Drizzle', 'Snow Grains,Haze', 'Snow Showers,Haze',
#        'Freezing Rain,Ice Pellets', 'Snow Showers,Snow Pellets,Fog',
#        'Snow Showers,Snow Pellets', 'Snow,Ice Pellets',
#        'Rain Showers,Snow Showers', 'Moderate Snow Showers',
#        'Thunderstorms,Heavy Rain Showers', 'Rain Showers,Drizzle,Fog',
#        'Rain Showers,Drizzle', 'Thunderstorms,Fog',
#        'Thunderstorms,Rain Showers,Haze', 'Drizzle,Snow Grains,Fog',
#        'Snow,Haze', 'Heavy Snow', 'Ice Pellets,Fog',
#        'Rain,Ice Pellet Showers', 'Rain,Snow,Ice Pellets',
#        'Snow,Ice Pellets,Fog', 'Rain Showers,Ice Pellet Showers',
#        'Rain,Drizzle', 'Freezing Drizzle,Snow,Ice Pellets',
#        'Thunderstorms,Rain', 'Snow Grains,Snow Showers',
#        'Ice Pellet Showers,Fog', 'Rain Showers,Ice Pellet Showers,Fog',
#        'Ice Pellets', 'Freezing Drizzle,Snow,Fog', 'Snow,Snow Pellets',
#        'Heavy Snow,Blowing Snow', 'Heavy Snow Showers',
#        'Rain,Snow,Ice Pellets,Fog', 'Rain,Drizzle,Snow Grains',
#        'Rain,Snow Grains', 'Drizzle,Snow Grains', 'Freezing Drizzle,Snow',
#        'Moderate Rain', 'Drizzle,Haze', 'Heavy Snow,Heavy Ice Pellets',
#        'Heavy Snow,Moderate Ice Pellets,Blowing Snow',
#        'Heavy Snow,Moderate Ice Pellets', 'Freezing Rain,Haze',
#        'Rain Showers,Ice Pellet Showers,Snow Showers', 'Freezing Fog',
#        'Thunderstorms,Snow', 'Rain,Snow,Haze',
#        'Freezing Rain,Snow,Ice Pellets',
#        'Freezing Drizzle,Snow Grains,Haze',
#        'Thunderstorms,Moderate Snow Showers', 'Freezing Rain,Snow',
#        'Freezing Drizzle,Ice Pellets',
#        'Moderate Snow Showers,Blowing Snow', 'Moderate Snow,Ice Pellets',
#        'Moderate Drizzle,Fog', 'Freezing Drizzle,Freezing Fog',
#        'Drizzle,Freezing Fog', 'Snow,Fog,Blowing Snow',
#        'Heavy Thunderstorms,Rain', 'Moderate Ice Pellets',
#        'Freezing Rain,Snow Grains', 'Ice Pellet Showers',
#        'Thunderstorms,Heavy Snow', 'Thunderstorms,Heavy Rain',
#        'Thunderstorms,Hail', 'Freezing Drizzle,Haze',
#        'Thunderstorms,Moderate Rain Showers,Hail',
#        'Rain,Snow Pellets,Fog', 'Rain Showers,Snow Pellets,Fog',
#        'Freezing Rain,Freezing Fog',
#        'Thunderstorms,Moderate Freezing Rain',
#        'Thunderstorms,Heavy Rain,Fog', 'Fog,Haze',
#        'Rain Showers,Moderate Ice Pellets', 'Moderate Freezing Drizzle',
#        'Moderate Ice Pellets,Snow Showers',
#        'Rain Showers,Ice Pellets,Fog', 'Rain,Snow,Snow Grains,Fog',
#        'Freezing Rain,Snow,Blowing Snow',
#        'Freezing Rain,Snow,Ice Pellets,Blowing Snow',
#        'Rain,Freezing Rain,Snow', 'Drizzle,Ice Pellets',
#        'Heavy Snow Showers,Blowing Snow', 'Freezing Rain,Snow,Fog',
#        'Moderate Freezing Rain', 'Moderate Freezing Rain,Fog'],
#       dtype=object)

# %%
clean_pre_df['weather'].nunique()
# Out:
# 157

# %% [markdown]
# dropping weather attribute due to high number values

# %%
clean_pre_df.drop(columns='weather', inplace=True)

# %%
clean_pre_df.head()
# Out:
#                      temp  dew_point_temp  rel_hum  wind_speed  visibility
# datetime
# 1994-01-01 00:00:00  -1.2            -3.8     83.0        15.0        19.3  \
# 1994-01-01 01:00:00  -0.9            -3.0     86.0        20.0        16.1
# 1994-01-01 02:00:00  -0.7            -3.2     83.0        15.0        16.1
# 1994-01-01 03:00:00  -0.8            -2.4     89.0        15.0        12.9
# 1994-01-01 04:00:00  -1.0            -3.3     84.0        19.0        16.1
#
#                      press  wind_chill  hour_of_day    year  month
# datetime
# 1994-01-01 00:00:00  99.91        -6.0          0.0  1994.0    1.0  \
# 1994-01-01 01:00:00  99.91        -6.0          1.0  1994.0    1.0
# 1994-01-01 02:00:00  99.87        -5.0          2.0  1994.0    1.0
# 1994-01-01 03:00:00  99.81        -5.0          3.0  1994.0    1.0
# 1994-01-01 04:00:00  99.77        -6.0          4.0  1994.0    1.0
#
#                      day_of_week  day_of_year  week_of_year  quarter
# datetime
# 1994-01-01 00:00:00          5.0          1.0          52.0      1.0  \
# 1994-01-01 01:00:00          5.0          1.0          52.0      1.0
# 1994-01-01 02:00:00          5.0          1.0          52.0      1.0
# 1994-01-01 03:00:00          5.0          1.0          52.0      1.0
# 1994-01-01 04:00:00          5.0          1.0          52.0      1.0
#
#                      hourly_demand     hmdxx
# datetime
# 1994-01-01 00:00:00        14422.0 -4.191500
# 1994-01-01 01:00:00        13845.0 -3.734133
# 1994-01-01 02:00:00        13372.0 -3.574269
# 1994-01-01 03:00:00        13025.0 -3.510459
# 1994-01-01 04:00:00        12869.0 -3.894137

# %%
clean_pre_df.shape
# Out:
# (219144, 16)

# %%
def check_null_values():
  null_counts = clean_pre_df.isnull().sum()
  total_rows = len(clean_pre_df)
  null_percent = (null_counts/total_rows)*100
  print(null_percent)

# %%
check_null_values()

# %%
clean_pre_df.drop(columns='wind_chill', inplace = True)

# %%
check_null_values()
# Out:
# temp              0.0
# dew_point_temp    0.0
# rel_hum           0.0
# wind_speed        0.0
# visibility        0.0
# press             0.0
# hour_of_day       0.0
# year              0.0
# month             0.0
# day_of_week       0.0
# day_of_year       0.0
# week_of_year      0.0
# quarter           0.0
# hourly_demand     0.0
# hmdxx             0.0
# dtype: float64

# %%
clean_pre_df.head()
# Out:
#                      temp  dew_point_temp  rel_hum  wind_speed  visibility
# datetime
# 1994-01-01 00:00:00  -1.2            -3.8     83.0        15.0        19.3  \
# 1994-01-01 01:00:00  -0.9            -3.0     86.0        20.0        16.1
# 1994-01-01 02:00:00  -0.7            -3.2     83.0        15.0        16.1
# 1994-01-01 03:00:00  -0.8            -2.4     89.0        15.0        12.9
# 1994-01-01 04:00:00  -1.0            -3.3     84.0        19.0        16.1
#
#                      press  hour_of_day    year  month  day_of_week
# datetime
# 1994-01-01 00:00:00  99.91          0.0  1994.0    1.0          5.0  \
# 1994-01-01 01:00:00  99.91          1.0  1994.0    1.0          5.0
# 1994-01-01 02:00:00  99.87          2.0  1994.0    1.0          5.0
# 1994-01-01 03:00:00  99.81          3.0  1994.0    1.0          5.0
# 1994-01-01 04:00:00  99.77          4.0  1994.0    1.0          5.0
#
#                      day_of_year  week_of_year  quarter  hourly_demand
# datetime
# 1994-01-01 00:00:00          1.0          52.0      1.0        14422.0  \
# 1994-01-01 01:00:00          1.0          52.0      1.0        13845.0
# 1994-01-01 02:00:00          1.0          52.0      1.0        13372.0
# 1994-01-01 03:00:00          1.0          52.0      1.0        13025.0
# 1994-01-01 04:00:00          1.0          52.0      1.0        12869.0
#
#                         hmdxx
# datetime
# 1994-01-01 00:00:00 -4.191500
# 1994-01-01 01:00:00 -3.734133
# 1994-01-01 02:00:00 -3.574269
# 1994-01-01 03:00:00 -3.510459
# 1994-01-01 04:00:00 -3.894137

# %%
clean_pre_df.shape
# Out:
# (219144, 15)

# %%
clean_pre_df.to_csv(clean_data_path/"clean_preprocessed_02.csv")
